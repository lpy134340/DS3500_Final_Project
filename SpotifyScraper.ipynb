# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import json
import os
from tqdm import tqdm
import pandas as pd

# %%
with open('client_secrets.json') as f:
    secrets = json.load(f)

os.environ['SPOTIPY_CLIENT_ID'] = secrets["Client_ID"]
os.environ['SPOTIPY_CLIENT_SECRET'] = secrets["Secret"]
os.environ['SPOTIPY_REDIRECT_URI'] = secrets["URL"]

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth())

# %%
genres = sp.recommendation_genre_seeds()
genres
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
#   'j-rock',
#   'jazz',
#   'k-pop',
#   'kids',
#   'latin',
#   'latino',
#   'malay',
#   'mandopop',
#   'metal',
#   'metal-misc',
#   'metalcore',
#   'minimal-techno',
#   'movies',
#   'mpb',
#   'new-age',
#   'new-release',
#   'opera',
#   'pagode',
#   'party',
#   'philippines-opm',
#   'piano',
#   'pop',
#   'pop-film',
#   'post-dubstep',
#   'power-pop',
#   'progressive-house',
#   'psych-rock',
#   'punk',
#   'punk-rock',
#   'r-n-b',
#   'rainy-day',
#   'reggae',
#   'reggaeton',
#   'road-trip',
#   'rock',
#   'rock-n-roll',
#   'rockabilly',
#   'romance',
#   'sad',
#   'salsa',
#   'samba',
#   'sertanejo',
#   'show-tunes',
#   'singer-songwriter',
#   'ska',
#   'sleep',
#   'songwriter',
#   'soul',
#   'soundtracks',
#   'spanish',
#   'study',
#   'summer',
#   'swedish',
#   'synth-pop',
#   'tango',
#   'techno',
#   'trance',
#   'trip-hop',
#   'turkish',
#   'work-out',
#   'world-music']}

# %%
len(genres["genres"])
# Out:
# 126

# %%
categories = sp.categories()
categories
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?offset=0&limit=20',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/pop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'pop',
#     'name': 'Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFPw634sFwguI',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/084155aeaa724ea1bd393a017d67b709',
#       'width': None}],
#     'id': '0JQ5DAqbMKFPw634sFwguI',
#     'name': 'EQUAL'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/mood',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/mood-274x274_976986a31ac8c49794cbdc7246fd5ad7_274x274.jpg',
#       'width': 274}],
#     'id': 'mood',
#     'name': 'Mood'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/decades',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/b611cf5145764c64b80e91ccd5f357c8',
#       'width': None}],
#     'id': 'decades',
#     'name': 'Decades'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/hiphop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg',
#       'width': 274}],
#     'id': 'hiphop',
#     'name': 'Hip-Hop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/in_the_car',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/57017d435c344bb28efba325b7c9e7c6.jpeg',
#       'width': None}],
#     'id': 'in_the_car',
#     'name': 'In the car'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/gaming',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/0d39395309ba47838ef12ce987f19d16.jpeg',
#       'width': None}],
#     'id': 'gaming',
#     'name': 'Gaming'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/wellness',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/3710b68657574bc79df14bd74629e5ac',
#       'width': None}],
#     'id': 'wellness',
#     'name': 'Wellness'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/workout',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/media/links/workout-274x274.jpg',
#       'width': None}],
#     'id': 'workout',
#     'name': 'Workout'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/chill',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/chill-274x274_4c46374f007813dd10b37e8d8fd35b4b_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'chill',
#     'name': 'Chill'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/focus',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/genre-images-square-274x274_5e50d72b846a198fcd2ca9b3aef5f0c8_274x274.jpg',
#       'width': 274}],
#     'id': 'focus',
#     'name': 'Focus'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/sleep',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/sleep-274x274_0d4f836af8fab7bf31526968073e671c_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'sleep',
#     'name': 'Sleep'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/party',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/7ee6530d5b3c4acc9a0957046bf11d63',
#       'width': None}],
#     'id': 'party',
#     'name': 'Party'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/indie_alt',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/fe06caf056474bc58862591cd60b57fc.jpeg',
#       'width': None}],
#     'id': 'indie_alt',
#     'name': 'Indie'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/metal',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/metal_27c921443fd0a5ba95b1b2c2ae654b2b_274x274.jpg',
#       'width': 274}],
#     'id': 'metal',
#     'name': 'Metal'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/rock',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/rock_9ce79e0a4ef901bbd10494f5b855d3cc_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'rock',
#     'name': 'Rock'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/edm_dance',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/edm-274x274_0ef612604200a9c14995432994455a6d_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'edm_dance',
#     'name': 'Dance/Electronic'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/dinner',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/dinner_1b6506abba0ba52c54e6d695c8571078_274x274.jpg',
#       'width': 274}],
#     'id': 'dinner',
#     'name': 'Cooking & Dining'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/jazz',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/568f37f1cab54136939d63bd1f59d40c',
#       'width': None}],
#     'id': 'jazz',
#     'name': 'Jazz'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/categories?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 40}}

# %%
cat_names = [i['name'] for i in categories['categories']['items']]
cat_names, len(cat_names)
# Out:
# (['Top Lists',
#   'Pop',
#   'EQUAL',
#   'Mood',
#   'Decades',
#   'Hip-Hop',
#   'In the car',
#   'Gaming',
#   'Wellness',
#   'Workout',
#   'Chill',
#   'Focus',
#   'Sleep',
#   'Party',
#   'Indie',
#   'Metal',
#   'Rock',
#   'Dance/Electronic',
#   'Cooking & Dining',
#   'Jazz'],
#  20)

# %%
track_dict = {}
n=0
for genre in genres["genres"][:2]:
    recs = sp.recommendations(seed_genres=[genre])
    for track in recs['tracks']:
        if track['name'] != '':
            track_dict[n] = {"name":track['name'],
                             "artists":[],
                             "genre":genre,
                             "spotifyID":track['id']}
            for artist in track['artists']:
                track_dict[n]["artists"].append(artist['name'])
            n+=1
track_dict
# Out:
# {0: {'name': 'Guaranteed',
#   'artists': ['Eddie Vedder'],
#   'genre': 'acoustic',
#   'spotifyID': '5sM2GI0vMNZL7tvfPQfByV'},
#  1: {'name': 'Daughters - Live at the Nokia Theatre, Los Angeles, CA - December 2007',
#   'artists': ['John Mayer'],
#   'genre': 'acoustic',
#   'spotifyID': '5bSPF76iSpI5p00BALV8uo'},
#  2: {'name': "I Still Haven't Found What I'm Looking For",
#   'artists': ['The Chimes'],
#   'genre': 'acoustic',
#   'spotifyID': '4EqCvUpjREyjrdxFnXbhAb'},
#  3: {'name': 'Comes And Goes (In Waves)',
#   'artists': ['Greg Laswell'],
#   'genre': 'acoustic',
#   'spotifyID': '2KhS0LVOw9ralhfbcIi7vL'},
#  4: {'name': 'Through Glass',
#   'artists': ['Stone Sour'],
#   'genre': 'acoustic',
#   'spotifyID': '76aadnUFFANRNDs6L3aqxw'},
#  5: {'name': 'Tonight, Tonight',
#   'artists': ['Tyler Ward', 'Alex G'],
#   'genre': 'acoustic',
#   'spotifyID': '1jKCHKZtGjXVRPN2Px368r'},
#  6: {'name': 'Wake Me Up',
#   'artists': ['Ed Sheeran'],
#   'genre': 'acoustic',
#   'spotifyID': '0ygAYQQy7bfDN6gH640bbl'},
#  7: {'name': 'How We Do (Party) - Live from Spotify NYC',
#   'artists': ['Rita Ora'],
#   'genre': 'acoustic',
#   'spotifyID': '0gw9t8io80CCz8XuH440PC'},
#  8: {'name': 'Gårdakvarnar och skit',
#   'artists': ['Håkan Hellström'],
#   'genre': 'acoustic',
#   'spotifyID': '33DxDFhE06bRC5tdHkIxhj'},
#  9: {'name': 'Little Things',
#   'artists': ['One Direction'],
#   'genre': 'acoustic',
#   'spotifyID': '7kSLdGdXLey7pzLsWpdg1h'},
#  10: {'name': 'Gravity - Live at the House of Blues, Chicago, Illinois, September 22, 2005',
#   'artists': ['John Mayer Trio'],
#   'genre': 'acoustic',
#   'spotifyID': '0FRoVng8IZZoS0ATxIgvuH'},
#  11: {'name': 'Briane',
#   'artists': ['Boyce Avenue'],
#   'genre': 'acoustic',
#   'spotifyID': '0hqnVPTK2zzWRcAJH3nx76'},
#  12: {'name': 'If It Means a Lot to You',
#   'artists': ['A Day To Remember'],
#   'genre': 'acoustic',
#   'spotifyID': '6J7cSyvSCnPwv3vqHchEfL'},
#  13: {'name': 'Budapest',
#   'artists': ['George Ezra'],
#   'genre': 'acoustic',
#   'spotifyID': '48gsLPdOUEDjr7P8Wvykne'},
#  14: {'name': 'Stockholm I Natt',
#   'artists': ['Peter Jöback'],
#   'genre': 'acoustic',
#   'spotifyID': '2Ax2a5arM3Jygi0EC3GJ2o'},
#  15: {'name': 'The Violet Hour',
#   'artists': ['The Civil Wars'],
#   'genre': 'acoustic',
#   'spotifyID': '6IN5LJsJQNPwzkytnTtrJC'},
#  16: {'name': 'White Winter Hymnal',
#   'artists': ['Fleet Foxes'],
#   'genre': 'acoustic',
#   'spotifyID': '1Er5JMNcguoBMFXxwZ7BWH'},
#  17: {'name': 'Beautiful',
#   'artists': ['Carly Rae Jepsen', 'Justin Bieber'],
#   'genre': 'acoustic',
#   'spotifyID': '7EOzfH8P0K4pKZpXE8JMmT'},
#  18: {'name': 'Who Says',
#   'artists': ['John Mayer'],
#   'genre': 'acoustic',
#   'spotifyID': '0HLWvLKQWpFdPhgk6ym58n'},
#  19: {'name': 'Life for Rent',
#   'artists': ['Dido'],
#   'genre': 'acoustic',
#   'spotifyID': '7bcP9k51f1VNCaFUyZ3P5M'},
#  20: {'name': 'Amandrai',
#   'artists': ['Ali Farka Touré'],
#   'genre': 'afrobeat',
#   'spotifyID': '5KvVJQzP8rYbxvbYXP3PO1'},
#  21: {'name': 'Kalabancoro',
#   'artists': ['Richard Bona', 'Salif Keita'],
#   'genre': 'afrobeat',
#   'spotifyID': '6vYkH6qUlMlmAP38yqeD1e'},
#  22: {'name': 'Matsotsi',
#   'artists': ['Chiwoniso'],
#   'genre': 'afrobeat',
#   'spotifyID': '5lI45e7n8XYQYgIh4FsMUW'},
#  23: {'name': 'Dirty Money',
#   'artists': ['Antibalas'],
#   'genre': 'afrobeat',
#   'spotifyID': '1LclSylnnHUKdrCZjS0V6M'},
#  24: {'name': 'Afro Disco Beat',
#   'artists': ['Tony Allen', 'Africa 70'],
#   'genre': 'afrobeat',
#   'spotifyID': '0tzvR9hZYdOBveJlgVz6Sy'},
#  25: {'name': 'Gentleman',
#   'artists': ['Fela Kuti'],
#   'genre': 'afrobeat',
#   'spotifyID': '1wCaldygX7fpq4Hx4LjluH'},
#  26: {'name': 'La Tortura (feat. Alejandro Sanz)',
#   'artists': ['Shakira', 'Alejandro Sanz'],
#   'genre': 'afrobeat',
#   'spotifyID': '5BSclXJTa9B0iURhUjZo50'},
#  27: {'name': 'I Faram Gami I Faram',
#   'artists': ['Mulatu Astatke'],
#   'genre': 'afrobeat',
#   'spotifyID': '7ATa1G9YTRrJtUXFHFs88z'},
#  28: {'name': 'Sa Golo',
#   'artists': ['Boubacar Traoré', 'Rokia Traoré'],
#   'genre': 'afrobeat',
#   'spotifyID': '1mDZpgKx9Xpg6ijl9DvdA6'},
#  29: {'name': 'Bouger bouger',
#   'artists': ['Magic System'],
#   'genre': 'afrobeat',
#   'spotifyID': '20xuHeZxFvNZtX8bXnwd9M'},
#  30: {'name': 'Ai Du',
#   'artists': ['Ali Farka Touré', 'Ry Cooder'],
#   'genre': 'afrobeat',
#   'spotifyID': '7vzhCpNntdmzI3yop3UckE'},
#  31: {'name': 'Ara',
#   'artists': ['Brymo'],
#   'genre': 'afrobeat',
#   'spotifyID': '1PTGzgjNWP4upVlCp95I6i'},
#  32: {'name': 'Djuru',
#   'artists': ['Amadou & Mariam'],
#   'genre': 'afrobeat',
#   'spotifyID': '3oJOtvPbyOqRPlFvspQP3o'},
#  33: {'name': 'Black President',
#   'artists': ['Eric Legnini & The Afro Jazz Beat'],
#   'genre': 'afrobeat',
#   'spotifyID': '6Nd9aoaL1lV3013tP5Meff'},
#  34: {'name': 'If Love Is A Crime',
#   'artists': ['2Baba', 'VIP'],
#   'genre': 'afrobeat',
#   'spotifyID': '1imfHroOMdTqspOIGnVtOs'},
#  35: {'name': 'Big Apple Boogaloo',
#   'artists': ['Brooklyn Funk Essentials'],
#   'genre': 'afrobeat',
#   'spotifyID': '6FrYPX8PWQUv3HljFo2vqT'},
#  36: {'name': 'Happy',
#   'artists': ['Pharrell Williams'],
#   'genre': 'afrobeat',
#   'spotifyID': '6NPVjNh8Jhru9xOmyQigds'},
#  37: {'name': 'Laidu',
#   'artists': ['Rokia Traoré'],
#   'genre': 'afrobeat',
#   'spotifyID': '05CF4ATpqROLTQVYABNZ3W'},
#  38: {'name': 'The Click Song',
#   'artists': ['Miriam Makeba'],
#   'genre': 'afrobeat',
#   'spotifyID': '2nlBaiNG1gIRLmsZnTmGbq'},
#  39: {'name': 'Létt ma',
#   'artists': ["Youssou N'Dour"],
#   'genre': 'afrobeat',
#   'spotifyID': '2VCIHU3m2zOoz9U4uTZqox'}}

# %%
df = pd.DataFrame(track_dict).T
df
# Out:
#                                                  name  \
# 0                                          Guaranteed
# 1   Daughters - Live at the Nokia Theatre, Los Ang...
# 2          I Still Haven't Found What I'm Looking For
# 3                           Comes And Goes (In Waves)
# 4                                       Through Glass
# 5                                    Tonight, Tonight
# 6                                          Wake Me Up
# 7           How We Do (Party) - Live from Spotify NYC
# 8                               Gårdakvarnar och skit
# 9                                       Little Things
# 10  Gravity - Live at the House of Blues, Chicago,...
# 11                                             Briane
# 12                           If It Means a Lot to You
# 13                                           Budapest
# 14                                   Stockholm I Natt
# 15                                    The Violet Hour
# 16                                White Winter Hymnal
# 17                                          Beautiful
# 18                                           Who Says
# 19                                      Life for Rent
# 20                                           Amandrai
# 21                                        Kalabancoro
# 22                                           Matsotsi
# 23                                        Dirty Money
# 24                                    Afro Disco Beat
# 25                                          Gentleman
# 26                  La Tortura (feat. Alejandro Sanz)
# 27                               I Faram Gami I Faram
# 28                                            Sa Golo
# 29                                      Bouger bouger
# 30                                              Ai Du
# 31                                                Ara
# 32                                              Djuru
# 33                                    Black President
# 34                                 If Love Is A Crime
# 35                                 Big Apple Boogaloo
# 36                                              Happy
# 37                                              Laidu
# 38                                     The Click Song
# 39                                            Létt ma
#
#                                 artists     genre               spotifyID
# 0                        [Eddie Vedder]  acoustic  5sM2GI0vMNZL7tvfPQfByV
# 1                          [John Mayer]  acoustic  5bSPF76iSpI5p00BALV8uo
# 2                          [The Chimes]  acoustic  4EqCvUpjREyjrdxFnXbhAb
# 3                        [Greg Laswell]  acoustic  2KhS0LVOw9ralhfbcIi7vL
# 4                          [Stone Sour]  acoustic  76aadnUFFANRNDs6L3aqxw
# 5                  [Tyler Ward, Alex G]  acoustic  1jKCHKZtGjXVRPN2Px368r
# 6                          [Ed Sheeran]  acoustic  0ygAYQQy7bfDN6gH640bbl
# 7                            [Rita Ora]  acoustic  0gw9t8io80CCz8XuH440PC
# 8                     [Håkan Hellström]  acoustic  33DxDFhE06bRC5tdHkIxhj
# 9                       [One Direction]  acoustic  7kSLdGdXLey7pzLsWpdg1h
# 10                    [John Mayer Trio]  acoustic  0FRoVng8IZZoS0ATxIgvuH
# 11                       [Boyce Avenue]  acoustic  0hqnVPTK2zzWRcAJH3nx76
# 12                  [A Day To Remember]  acoustic  6J7cSyvSCnPwv3vqHchEfL
# 13                        [George Ezra]  acoustic  48gsLPdOUEDjr7P8Wvykne
# 14                       [Peter Jöback]  acoustic  2Ax2a5arM3Jygi0EC3GJ2o
# 15                     [The Civil Wars]  acoustic  6IN5LJsJQNPwzkytnTtrJC
# 16                        [Fleet Foxes]  acoustic  1Er5JMNcguoBMFXxwZ7BWH
# 17    [Carly Rae Jepsen, Justin Bieber]  acoustic  7EOzfH8P0K4pKZpXE8JMmT
# 18                         [John Mayer]  acoustic  0HLWvLKQWpFdPhgk6ym58n
# 19                               [Dido]  acoustic  7bcP9k51f1VNCaFUyZ3P5M
# 20                    [Ali Farka Touré]  afrobeat  5KvVJQzP8rYbxvbYXP3PO1
# 21          [Richard Bona, Salif Keita]  afrobeat  6vYkH6qUlMlmAP38yqeD1e
# 22                          [Chiwoniso]  afrobeat  5lI45e7n8XYQYgIh4FsMUW
# 23                          [Antibalas]  afrobeat  1LclSylnnHUKdrCZjS0V6M
# 24              [Tony Allen, Africa 70]  afrobeat  0tzvR9hZYdOBveJlgVz6Sy
# 25                          [Fela Kuti]  afrobeat  1wCaldygX7fpq4Hx4LjluH
# 26            [Shakira, Alejandro Sanz]  afrobeat  5BSclXJTa9B0iURhUjZo50
# 27                     [Mulatu Astatke]  afrobeat  7ATa1G9YTRrJtUXFHFs88z
# 28      [Boubacar Traoré, Rokia Traoré]  afrobeat  1mDZpgKx9Xpg6ijl9DvdA6
# 29                       [Magic System]  afrobeat  20xuHeZxFvNZtX8bXnwd9M
# 30         [Ali Farka Touré, Ry Cooder]  afrobeat  7vzhCpNntdmzI3yop3UckE
# 31                              [Brymo]  afrobeat  1PTGzgjNWP4upVlCp95I6i
# 32                    [Amadou & Mariam]  afrobeat  3oJOtvPbyOqRPlFvspQP3o
# 33  [Eric Legnini & The Afro Jazz Beat]  afrobeat  6Nd9aoaL1lV3013tP5Meff
# 34                         [2Baba, VIP]  afrobeat  1imfHroOMdTqspOIGnVtOs
# 35           [Brooklyn Funk Essentials]  afrobeat  6FrYPX8PWQUv3HljFo2vqT
# 36                  [Pharrell Williams]  afrobeat  6NPVjNh8Jhru9xOmyQigds
# 37                       [Rokia Traoré]  afrobeat  05CF4ATpqROLTQVYABNZ3W
# 38                      [Miriam Makeba]  afrobeat  2nlBaiNG1gIRLmsZnTmGbq
# 39                     [Youssou N'Dour]  afrobeat  2VCIHU3m2zOoz9U4uTZqox
